# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
import seaborn as sns
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error
import itertools
import pandas as pd
import pickle
import bikes
import mse
import prediction_plots as pplot
import warnings
from pmdarima import auto_arima
warnings.filterwarnings("ignore")

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
master = pd.read_csv('master.csv')

# %%
plt.plot(master);

# %%
master.set_index('date_of_trip', inplace = True)

# %%
master.index = pd.to_datetime(master.index)

# %%
master_m = master.resample('m').sum()

# %%
dc_temps = pd.read_csv('dc_temps.csv')
dc_precips = pd.read_csv('dc_precips.csv')

# %%
rename_dict = {}
rename_dict['Unnamed: 0'] = 'Year'
dc_temps.rename(columns = rename_dict, inplace = True)
dc_precips.rename(columns = rename_dict, inplace = True)
dc_temps.set_index('Year', inplace = True)
dc_precips.set_index('Year', inplace = True)

# %%
dc_temps_stack = dc_temps.stack()

# %%
dc_precips_stack = dc_precips.stack()

# %%
master_m['avg_temp'] = np.array(dc_temps_stack)
master_m['avg_precips'] = np.array(dc_precips_stack)

# %%
master_m.head()
# Out:
#               count  avg_temp  avg_precips
# date_of_trip
# 2010-09-30     4002      75.5         6.02
# 2010-10-31    35957      61.6         3.40
# 2010-11-30    47390      50.5         2.22
# 2010-12-31    28248      34.6         1.78
# 2011-01-31    37503      33.7         2.25

# %%
fig = plt.figure(figsize = (15,10))

plt.plot(master_m['count'], lw = 2, color = 'mediumseagreen')

plt.xlabel('Date', fontsize = 20);
plt.ylabel('Count', fontsize = 20);

plt.title('Number of Bike Rentals per Week, Time Series', fontsize = 30);
plt.title('Number of Bike Rentals per Month, Time Series', fontsize = 30);

# %%
TRAIN = .7
train_index_m = int(len(master_m)*TRAIN) + 1
train_m = master_m.iloc[:train_index_m]
test_m = master_m.iloc[train_index_m:]

# %%
fig = plt.figure(figsize = (15,8))

plt.plot(train_m['count'], lw = 3)
plt.plot(test_m['count'], lw = 3, color = 'navy')
plt.legend(['Train', 'Test'],prop={'size': 24}) 

plt.xlabel('Date', fontsize = 20);
plt.ylabel('Count', fontsize = 20);

plt.title('Number of Bike Rentals per Month, Time Series', fontsize = 30);

# %%
decomposition = seasonal_decompose(train_m['count'], freq=12)
fig = plt.figure()
fig = decomposition.plot()
fig.set_size_inches(15, 8)

# %%
def test_stationarity(timeseries, window):
    
    #Determing rolling statistics
    rolmean = timeseries.rolling(window=window).mean()
    rolstd = timeseries.rolling(window=window).std()

    #Plot rolling statistics:
    fig = plt.figure(figsize=(12, 8))
    orig = plt.plot(timeseries.iloc[window:], color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %% [markdown]
# ## First Order Difference

# %%
master_1_diff = master_m.copy()
master_1_diff['count'] = master_m['count'].diff()
master_1_diff.dropna(inplace = True)

# %%
test_stationarity(master_1_diff['count'], 12)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.685876
# p-value                         0.076514
# #Lags Used                     12.000000
# Number of Observations Used    93.000000
# Critical Value (1%)            -3.502705
# Critical Value (5%)            -2.893158
# Critical Value (10%)           -2.583637
# dtype: float64

# %% [markdown]
# ## Second Order Difference

# %%
master_2_diff = master_m.copy()
master_2_diff['count'] = master_m['count'].diff().diff()
master_2_diff.dropna(inplace = True)

# %%
test_stationarity(master_2_diff['count'], 12)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.090460e+01
# p-value                        1.136531e-19
# #Lags Used                     1.100000e+01
# Number of Observations Used    9.300000e+01
# Critical Value (1%)           -3.502705e+00
# Critical Value (5%)           -2.893158e+00
# Critical Value (10%)          -2.583637e+00
# dtype: float64

# %% [markdown]
# ## First Seasonal Difference

# %%
master_1_season = master_m.copy()
master_1_season = master_1_season - master_1_season.shift(12)
master_1_season.dropna(inplace = True)

# %%
test_stationarity(master_1_season['count'], 12)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.686766
# p-value                         0.850148
# #Lags Used                      9.000000
# Number of Observations Used    85.000000
# Critical Value (1%)            -3.509736
# Critical Value (5%)            -2.896195
# Critical Value (10%)           -2.585258
# dtype: float64

# %% [markdown]
# ## Second Seasonal Difference

# %%
master_2_season = master_m.copy()
master_2_season = master_2_season - master_2_season.shift(12)
master_2_season.dropna(inplace = True)

# %%
test_stationarity(master_2_season['count'], 12)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.686766
# p-value                         0.850148
# #Lags Used                      9.000000
# Number of Observations Used    85.000000
# Critical Value (1%)            -3.509736
# Critical Value (5%)            -2.896195
# Critical Value (10%)           -2.585258
# dtype: float64

# %% [markdown]
# ## First Seasonal Difference of First Order Difference

# %%
master_1_season_diff_1_diff = master_1_diff.copy()
master_1_season_diff_1_diff['count'] = master_1_season_diff_1_diff['count'] - master_1_season_diff_1_diff['count'].shift(12)
master_1_season_diff_1_diff.dropna(inplace = True)

# %%
test_stationarity(master_1_season_diff_1_diff['count'], 12)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -5.776158e+00
# p-value                        5.253633e-07
# #Lags Used                     8.000000e+00
# Number of Observations Used    8.500000e+01
# Critical Value (1%)           -3.509736e+00
# Critical Value (5%)           -2.896195e+00
# Critical Value (10%)          -2.585258e+00
# dtype: float64

# %% [markdown]
# ## First Seasonal Difference on Second Order Difference

# %%
master_1_season_diff_2_diff = master_2_diff.copy()
master_1_season_diff_2_diff['count'] = master_1_season_diff_2_diff['count'] - master_1_season_diff_2_diff['count'].shift(12)
master_1_season_diff_2_diff.dropna(inplace = True)

# %%
test_stationarity(master_1_season_diff_2_diff['count'], 12)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.564378e+00
# p-value                        8.228885e-09
# #Lags Used                     1.100000e+01
# Number of Observations Used    8.100000e+01
# Critical Value (1%)           -3.513790e+00
# Critical Value (5%)           -2.897943e+00
# Critical Value (10%)          -2.586191e+00
# dtype: float64

# %% [markdown]
# ## Second Seasonal Difference on First Order Difference

# %%
master_2_season_diff_1_diff = master_1_season_diff_1_diff.copy()
master_2_season_diff_1_diff['count'] = master_1_season_diff_1_diff.diff()
master_2_season_diff_1_diff.dropna(inplace = True)

# %%
test_stationarity(master_2_season_diff_1_diff['count'], 12)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.564378e+00
# p-value                        8.228885e-09
# #Lags Used                     1.100000e+01
# Number of Observations Used    8.100000e+01
# Critical Value (1%)           -3.513790e+00
# Critical Value (5%)           -2.897943e+00
# Critical Value (10%)          -2.586191e+00
# dtype: float64

# %% [markdown]
# ## Second Seasonal Difference on Second Order Difference

# %%
master_2_season_diff_2_diff = master_1_season_diff_2_diff.copy()
master_2_season_diff_2_diff['count'] = master_1_season_diff_2_diff.diff()
master_2_season_diff_2_diff.dropna(inplace = True)

# %%
test_stationarity(master_2_season_diff_2_diff['count'], 12)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.303045e+00
# p-value                        3.375338e-08
# #Lags Used                     1.200000e+01
# Number of Observations Used    7.900000e+01
# Critical Value (1%)           -3.515977e+00
# Critical Value (5%)           -2.898886e+00
# Critical Value (10%)          -2.586694e+00
# dtype: float64

# %% [markdown]
# ## Natural Log of Data

# %%
master_m_log = master_m.copy()
master_m_log['count'] = np.log(master_m['count'])

# %%
test_stationarity(master_m_log['count'], 12)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -5.527687
# p-value                         0.000002
# #Lags Used                     12.000000
# Number of Observations Used    94.000000
# Critical Value (1%)            -3.501912
# Critical Value (5%)            -2.892815
# Critical Value (10%)           -2.583454
# dtype: float64

# %% [markdown]
# ## First Order Difference of Log Data

# %%
master_1_diff_log = master_m_log.copy()
master_1_diff_log['count'] = master_m_log.diff()
master_1_diff_log.dropna(inplace = True)

# %%
test_stationarity(master_1_diff_log['count'], 12)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -3.685683
# p-value                         0.004319
# #Lags Used                     13.000000
# Number of Observations Used    92.000000
# Critical Value (1%)            -3.503515
# Critical Value (5%)            -2.893508
# Critical Value (10%)           -2.583824
# dtype: float64

# %% [markdown]
# ## Log of First Order Difference

# %%
master_log_1_diff = master_1_diff.copy()
master_log_1_diff['count'] = np.log(master_1_diff)

# %%
test_stationarity(master_log_1_diff['count'], 12)
# Out:
# Results of Dickey-Fuller Test:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-117-15f8e5c72824> in <module>
# ----> 1 test_stationarity(master_log_1_diff['count'], 12)
#
# <ipython-input-77-398a9de14110> in test_stationarity(timeseries, window)
#      16     #Perform Dickey-Fuller test:
#      17     print ('Results of Dickey-Fuller Test:')
# ---> 18     dftest = adfuller(timeseries, autolag='AIC')
#      19     dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
#      20     for key,value in dftest[4].items():
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     255         if not regresults:
#     256             icbest, bestlag = _autolag(OLS, xdshort, fullRHS, startlag,
# ...

# %% [markdown]
# ## Second Order Difference of Log Data

# %%
master_2_diff_log = master_m_log.copy()
master_2_diff_log['count'] = master_m_log.diff().diff()
master_2_diff_log.dropna(inplace = True)

# %%
test_stationarity(master_2_diff_log['count'], 12)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -9.502417e+00
# p-value                        3.417002e-16
# #Lags Used                     1.200000e+01
# Number of Observations Used    9.200000e+01
# Critical Value (1%)           -3.503515e+00
# Critical Value (5%)           -2.893508e+00
# Critical Value (10%)          -2.583824e+00
# dtype: float64

# %% [markdown]
# ## First Seasonal Difference of Log Data

# %%
master_1_season_log = master_m_log.copy()
master_1_season_log['count'] = master_1_season_log['count'] - master_1_season_log['count'].shift(12)
master_1_season_log.dropna(inplace = True)

# %%
test_stationarity(master_1_season_log['count'], 12)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.960104
# p-value                         0.038792
# #Lags Used                     11.000000
# Number of Observations Used    83.000000
# Critical Value (1%)            -3.511712
# Critical Value (5%)            -2.897048
# Critical Value (10%)           -2.585713
# dtype: float64

# %% [markdown]
# ## Second Seasonal Difference of Log Data

# %%
master_2_season_log = master_1_season_log.copy()
master_2_season_log['count'] = master_2_season_log['count'] - master_2_season_log['count'].shift(12)
master_2_season_log.dropna(inplace = True)

# %%
test_stationarity(master_2_season_log['count'], 12)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.271006
# p-value                         0.181490
# #Lags Used                     11.000000
# Number of Observations Used    71.000000
# Critical Value (1%)            -3.526005
# Critical Value (5%)            -2.903200
# Critical Value (10%)           -2.588995
# dtype: float64
